# %%
from PIL import Image,ImageDraw , ImageFont, ImageFilter, ImageEnhance

# %%
img1 = Image.open('image.jpeg')
img2 = Image.open('image1.jpeg')
img3 = Image.open('image3.png')
img4 = Image.open('log.png')

# %%
print(img4.info)
print(img4.format)
print(img4.mode)
# Out:
# {'dpi': (96.012, 96.012)}
# PNG
# RGBA

# %%
iml1 = img1.resize((200,150))
iml1
# Out:
# <PIL.Image.Image image mode=RGB size=200x150>

# %%
iml1.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=200x150>

# %%
iml1.rotate(45).save('image_rot_45.jpeg')

# %%
img2.size
# Out:
# (332, 152)

# %%
img2.crop((0,0,100,100)).show()  ##(left,top, right,lower)

# %%
img3 = img3.resize(img2.size)

# %%
img3.convert(img2.mode)
print(img2.mode,img3.mode)
print(img3.size,img2.size)
# Out:
# RGB RGB
# (332, 152) (332, 152)

# %%
Image.blend(img2,img3,.5).show()  # image blending

# %%
img3
# Out:
# <PIL.Image.Image image mode=RGB size=332x152>

# %%
img3c = img3.copy()
im3c = img3.paste(img4,(100,50),img4)
img3.save('image_rot.jpg')

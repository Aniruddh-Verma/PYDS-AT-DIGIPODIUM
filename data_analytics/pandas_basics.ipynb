# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# it is used to do time date analysis


df = pd.read_csv('incidents_small.csv',parse_dates=['Date'])
df
# Out:
# C:\Users\aniruddh\AppData\Local\Temp\ipykernel_4288\2886241513.py:4: DtypeWarning:
#
# Columns (1,2,3,5,6,7,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#          IncidntNum      Category  \
# 0       120058272.0   WEAPON LAWS
# 1       120058272.0   WEAPON LAWS
# 2       141059263.0      WARRANTS
# 3       160013662.0  NON-CRIMINAL
# 4       160002740.0  NON-CRIMINAL
# ...             ...           ...
# 150495          NaN           NaN
# 150496          NaN           NaN
# 150497          NaN           NaN
# 150498          NaN           NaN
# 150499          NaN           NaN
#
#                                               Descript DayOfWeek       Date  \
# 0                            POSS OF PROHIBITED WEAPON    Friday 2016-01-29
# 1       FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday 2016-01-29
# 2                                       WARRANT ARREST    Monday 2016-04-25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150500 entries, 0 to 150499
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IncidntNum  10019 non-null  float64
#  1   Category    10019 non-null  object
#  2   Descript    10019 non-null  object
#  3   DayOfWeek   10019 non-null  object
#  4   Date        10019 non-null  datetime64[ns]
#  5   Time        10019 non-null  object
#  6   PdDistrict  10019 non-null  object
#  7   Resolution  10019 non-null  object
#  8   Address     10019 non-null  object
#  9   X           10019 non-null  float64
#  10  Y           10019 non-null  float64
#  11  Location    10019 non-null  object
#  12  PdId        10019 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 14.9+ MB

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (10019, 13)

# %%
df.sort_values(by=['IncidntNum'], ascending=False,inplace=True)
df.head(30)
# Out:
#        IncidntNum        Category  \
# 9554  160939676.0         ASSAULT
# 9986  160895846.0  OTHER OFFENSES
# 9964  160893652.0    NON-CRIMINAL
# 9963  160893464.0     WEAPON LAWS
# 9962  160893395.0         ASSAULT
# 9953  160892842.0  SUSPICIOUS OCC
# 9952  160892836.0   LARCENY/THEFT
# 9951  160892820.0         ASSAULT
# 9950  160892814.0  OTHER OFFENSES
# 9945  160892591.0         ASSAULT
# 9944  160892585.0       VANDALISM
# 9933  160891662.0         ASSAULT
# 9860  160889786.0        BURGLARY
# 9859  160889764.0  OTHER OFFENSES
# 9858  160889742.0  OTHER OFFENSES
# 9857  160889736.0        WARRANTS
# 9826  160887677.0         ASSAULT
# 9727  160884689.0   VEHICLE THEFT
# 9715  160883766.0     WEAPON LAWS
# 9714  160883750.0        BURGLARY
# 9711  160883255.0   LARCENY/THEFT
# 9710  160883249.0       VANDALISM
# 9644  160880427.0  OTHER OFFENSES
# 9645  160880427.0       VANDALISM
# 9611  160877424.0       VANDALISM
# 9603  160876642.0         ASSAULT
# ...

# %%
df.sort_values(by=['Date','IncidntNum'], ascending=False,inplace=True)
df.head(30)
# Out:
#        IncidntNum        Category  \
# 2467  150273337.0        WARRANTS
# 115   150480366.0   VEHICLE THEFT
# 116   150480366.0     DRUNKENNESS
# 117   150480366.0       VANDALISM
# 118   150480366.0       VANDALISM
# 5332  160220970.0           FRAUD
# 9554  160939676.0         ASSAULT
# 9964  160893652.0    NON-CRIMINAL
# 9963  160893464.0     WEAPON LAWS
# 9962  160893395.0         ASSAULT
# 9953  160892842.0  SUSPICIOUS OCC
# 9951  160892820.0         ASSAULT
# 9950  160892814.0  OTHER OFFENSES
# 9945  160892591.0         ASSAULT
# 9944  160892585.0       VANDALISM
# 9933  160891662.0         ASSAULT
# 9860  160889786.0        BURGLARY
# 9857  160889736.0        WARRANTS
# 9986  160895846.0  OTHER OFFENSES
# 9859  160889764.0  OTHER OFFENSES
# 9826  160887677.0         ASSAULT
# 9727  160884689.0   VEHICLE THEFT
# 9715  160883766.0     WEAPON LAWS
# 9710  160883249.0       VANDALISM
# 9714  160883750.0        BURGLARY
# 9711  160883255.0   LARCENY/THEFT
# ...

# %%
category_count = df.Category.value_counts().reset_index()
category_count.columns = ['Category','Case_counts']
category_count
# Out:
#                        Category  Case_counts
# 0                 LARCENY/THEFT         1566
# 1                OTHER OFFENSES         1476
# 2                  NON-CRIMINAL         1242
# 3                       ASSAULT         1075
# 4                      WARRANTS          555
# 5                 VEHICLE THEFT          529
# 6                     VANDALISM          475
# 7                      BURGLARY          458
# 8                SUSPICIOUS OCC          443
# 9                 DRUG/NARCOTIC          396
# 10               MISSING PERSON          364
# 11                      ROBBERY          268
# 12                        FRAUD          188
# 13              SECONDARY CODES          146
# 14                     TRESPASS          146
# 15                  WEAPON LAWS          141
# 16            RECOVERED VEHICLE           77
# 17       SEX OFFENSES, FORCIBLE           74
# 18                 PROSTITUTION           59
# 19              STOLEN PROPERTY           55
# ...

# %%
category_count_top10 = category_count.head(10)
px.pie(category_count_top10,'Category','Case_counts')

# %%
df.head()
# Out:
#        IncidntNum       Category  \
# 2467  150273337.0       WARRANTS
# 115   150480366.0  VEHICLE THEFT
# 116   150480366.0    DRUNKENNESS
# 117   150480366.0      VANDALISM
# 118   150480366.0      VANDALISM
#
#                                           Descript  DayOfWeek       Date  \
# 2467                                WARRANT ARREST  Wednesday 2016-12-21
# 115                   STOLEN AND RECOVERED VEHICLE   Thursday 2016-12-08
# 116   UNDER INFLUENCE OF ALCOHOL IN A PUBLIC PLACE   Thursday 2016-12-08
# 117                  MALICIOUS MISCHIEF, VANDALISM   Thursday 2016-12-08
# 118      MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Thursday 2016-12-08
#
#        Time  PdDistrict      Resolution                Address           X  \
# 2467  18:17  TENDERLOIN  ARREST, BOOKED  300 Block of JONES ST -122.412759
# 115   15:00    NORTHERN  ARREST, BOOKED      PINE ST / POLK ST -122.420497
# 116   15:00    NORTHERN  ARREST, BOOKED      PINE ST / POLK ST -122.420497
# ...

# %% [markdown]
# #### Find the most commom way of handling incidents in SanFrancisco

# %%
#df.drop(df[df.Resolution == 'NONE'].index())

# %%
df1 = df.value_counts('Resolution').reset_index()
df1.columns = ['Resolution','Number']
df1
# Out:
#                                 Resolution  Number
# 0                                     NONE    6390
# 1                           ARREST, BOOKED    3356
# 2                                UNFOUNDED     159
# 3                          JUVENILE BOOKED      56
# 4                    EXCEPTIONAL CLEARANCE      28
# 5                            ARREST, CITED      18
# 6   CLEARED-CONTACT JUVENILE FOR MORE INFO       5
# 7                                  LOCATED       3
# 8         COMPLAINANT REFUSES TO PROSECUTE       1
# 9                        JUVENILE DIVERTED       1
# 10                          NOT PROSECUTED       1
# 11                       PSYCHOPATHIC CASE       1

# %%
Resolution_5 = df1.head(6)
px.pie(Resolution_5,'Resolution','Number')

# %%
# how to get only november entry
date = df[df.Date.dt.month == 10].Category.value_counts().reset_index()
date.columns = ['Category','Values']
date
# Visualize the Data
# Out:
#            Category  Values
# 0    OTHER OFFENSES      32
# 1     LARCENY/THEFT      25
# 2           ASSAULT      18
# 3      NON-CRIMINAL      16
# 4     VEHICLE THEFT      12
# 5         VANDALISM      12
# 6     DRUG/NARCOTIC      10
# 7    SUSPICIOUS OCC      10
# 8          BURGLARY       9
# 9          WARRANTS       8
# 10   MISSING PERSON       7
# 11      WEAPON LAWS       6
# 12          ROBBERY       5
# 13  SECONDARY CODES       5
# 14     PROSTITUTION       4
# 15         TRESPASS       2
# 16            FRAUD       1

# %%
px.bar(date,'Category','Values')

# %% [markdown]
# ### Group incident categories by months

# %%
month_Wise_case = df.groupby(df.Date.dt.month)['Category'].count().reset_index()
month_Wise_case.columns = ['Month','Case_count']
month_Wise_case
# Out:
#     Month  Case_count
# 0       1        2097
# 1       2        2387
# 2       3        3361
# 3       4        1334
# 4       5          82
# 5       6         111
# 6       7         149
# 7       8         160
# 8       9         138
# 9      10         182
# 10     11          13
# 11     12           5

# %%
def num_to_months(num):
      months = ['january','february','march','april','may','june','july','august','september','october','november','december']
      return months[num-1]

# %%
month_Wise_case['Month'] = month_Wise_case['Month'].apply(num_to_months)

# %%
px.bar(month_Wise_case,'Month','Case_count')

# %% [markdown]
# ### PIVOT TABLE

# %%
print(df.columns.to_list())
# Out:
# ['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'PdId']

# %%
df.pivot_table(index='Category',columns='Resolution',values='IncidntNum',aggfunc='count')
# Out:
# Resolution                   ARREST, BOOKED  ARREST, CITED  \
# Category
# ARSON                                   6.0            NaN
# ASSAULT                               427.0            NaN
# BRIBERY                                 4.0            NaN
# BURGLARY                               79.0            NaN
# DISORDERLY CONDUCT                     18.0            NaN
# DRIVING UNDER THE INFLUENCE            29.0            NaN
# DRUG/NARCOTIC                         364.0            1.0
# DRUNKENNESS                            39.0            NaN
# EMBEZZLEMENT                            NaN            NaN
# EXTORTION                               NaN            NaN
# FAMILY OFFENSES                         2.0            NaN
# FORGERY/COUNTERFEITING                 13.0            NaN
# FRAUD                                  26.0            NaN
# GAMBLING                                1.0            NaN
# KIDNAPPING                             10.0            NaN
# ...

# %%
df.pivot_table(index='Category',columns='DayOfWeek',values='IncidntNum',aggfunc='count')
# Out:
# DayOfWeek                    Friday  Monday  Saturday  Sunday  Thursday  \
# Category
# ARSON                           7.0     4.0       3.0     5.0       5.0
# ASSAULT                       161.0   157.0     169.0   155.0     137.0
# BRIBERY                         2.0     1.0       2.0     3.0       NaN
# BURGLARY                       77.0    60.0      55.0    59.0      72.0
# DISORDERLY CONDUCT              3.0    13.0       5.0     3.0       5.0
# DRIVING UNDER THE INFLUENCE     6.0     2.0      13.0     3.0       7.0
# DRUG/NARCOTIC                  53.0    73.0      46.0    52.0      45.0
# DRUNKENNESS                     8.0     4.0      11.0     6.0      10.0
# EMBEZZLEMENT                    NaN     NaN       1.0     1.0       2.0
# EXTORTION                       1.0     2.0       NaN     2.0       NaN
# FAMILY OFFENSES                 1.0     NaN       NaN     1.0       2.0
# FORGERY/COUNTERFEITING          7.0     6.0       6.0     6.0       9.0
# ...

# %% [markdown]
# ### APPLY A FUNCTION

# %%
df['Category'] = df['Category'].apply(lambda val: val.lower())
df['Descript'] = df['Descript'].apply(lambda val: val.lower())
df['PdDistrict'] = df['PdDistrict'].apply(lambda val: val.lower())
df['Resolution'] = df['Resolution'].apply(lambda val: val.lower())
df.head()
# Out:
#        IncidntNum       Category  \
# 2467  150273337.0       warrants
# 115   150480366.0  vehicle theft
# 116   150480366.0    drunkenness
# 117   150480366.0      vandalism
# 118   150480366.0      vandalism
#
#                                           Descript  DayOfWeek       Date  \
# 2467                                warrant arrest  Wednesday 2016-12-21
# 115                   stolen and recovered vehicle   Thursday 2016-12-08
# 116   under influence of alcohol in a public place   Thursday 2016-12-08
# 117                  malicious mischief, vandalism   Thursday 2016-12-08
# 118      malicious mischief, vandalism of vehicles   Thursday 2016-12-08
#
#        Time  PdDistrict      Resolution                Address           X  \
# 2467  18:17  tenderloin  arrest, booked  300 Block of JONES ST -122.412759
# 115   15:00    northern  arrest, booked      PINE ST / POLK ST -122.420497
# 116   15:00    northern  arrest, booked      PINE ST / POLK ST -122.420497
# ...

# %%
tips = px.data.tips()   ## U.S restautrant tips dataset
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# finding the value of foodbill
tips.total_bill - tips.tip
# Out:
# 0      15.98
# 1       8.68
# 2      17.51
# 3      20.37
# 4      20.98
#        ...
# 239    23.11
# 240    25.18
# 241    20.67
# 242    16.07
# 243    15.78
# Length: 244, dtype: float64

# %%
# adding a new columns to the data sets(Augmentation) 
tips['food_bill'] = tips.total_bill - tips.tip
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  food_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2      15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3       8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3      17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2      20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4      20.98

# %%
tips.sort_values(by='food_bill',ascending=False,inplace=True)
tips.head()
# Out:
#      total_bill    tip     sex smoker  day    time  size  food_bill
# 156       48.17   5.00    Male     No  Sun  Dinner     6      43.17
# 182       45.35   3.50    Male    Yes  Sun  Dinner     3      41.85
# 102       44.30   2.50  Female    Yes  Sat  Dinner     3      41.80
# 59        48.27   6.73    Male     No  Sat  Dinner     4      41.54
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3      40.81

# %%
tips.pivot_table(index='day',columns='sex',values='food_bill',aggfunc=['max','min'])
# Out:
#         max           min
# sex  Female   Male Female  Male
# day
# Fri   19.50  35.44   4.75  6.66
# Sat   41.80  41.54   2.07  6.30
# Sun   30.26  43.17   5.60  2.10
# Thur  38.11  36.19   6.85  5.51

# %% [markdown]
# # general syntax of plotly
# '''
# px.function(dataframe , colname1 , colname2 , othersettings)
# '''

# %%
px.bar(tips.head(10) , ['food_bill','total_bill'])

# %%
px.box(tips,'total_bill')

# %%
px.box(tips,'total_bill', color = 'sex')

# %%
px.box(tips,'total_bill', color = 'smoker')

# %%
px.box(tips , 'tip' , color = 'sex')

# %%
px.violin(tips, 'tip', color= 'sex')

# %%
px.scatter(tips , 'total_bill' , 'tip' , color='sex' , facet_col='day')

# %%
px.scatter(tips , 'total_bill' , 'tip' , color='sex' , facet_col=tips['day'].sort_values())

# %%
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
dfc = df[df.country == 'India']

# %%
px.bar(dfc , 'year' , 'lifeExp' , title=' Indian Life Expecancy')

# %%
dfc1 = df[df.country == 'Albania']

# %%
px.funnel(dfc1 , 'year' , 'lifeExp' , title='Albania Lifes Expectancy')

# %%
px.scatter_3d(df , x= 'year' , y = 'lifeExp' , z = 'pop' , hover_data=['country'] , size= 'pop' , color='country')

# %%
px.scatter(df , x= 'lifeExp' , y = 'gdpPercap' , hover_data=['country'] , color='continent', size= 'pop' , animation_frame='year' , animation_group='country' )

# %%
continents1 = df.groupby(['continent','year']).mean().reset_index()
continents1
# Out:
# C:\Users\aniruddh\AppData\Local\Temp\ipykernel_4288\310430263.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#    continent  year    lifeExp           pop     gdpPercap     iso_num
# 0     Africa  1952  39.135500  4.570010e+06   1252.572466  458.826923
# 1     Africa  1957  41.266346  5.093033e+06   1385.236062  458.826923
# 2     Africa  1962  43.319442  5.702247e+06   1598.078825  458.826923
# 3     Africa  1967  45.334538  6.447875e+06   2050.363801  458.826923
# 4     Africa  1972  47.450942  7.305376e+06   2339.615674  458.826923
# 5     Africa  1977  49.580423  8.328097e+06   2585.938508  458.826923
# 6     Africa  1982  51.592865  9.602857e+06   2481.592960  458.826923
# 7     Africa  1987  53.344788  1.105450e+07   2282.668991  458.826923
# ...

# %%
px.sunburst(df , path=['continent','country','year'],values='pop' )

# %%
px.icicle(df,path=['continent','country','year'],values='pop')
